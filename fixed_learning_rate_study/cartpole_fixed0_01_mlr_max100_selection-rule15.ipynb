# %%
import gym
import numpy as np
# from reinforce_tf2 import Agent
# from utils import plotLearning
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.optimizers import Adam, SGD
import numpy as np
import time
import matplotlib.pyplot as plt
import pymc3 as pm
from scipy.stats import beta
import scipy


class PolicyGradientNetwork(keras.Model):
    def __init__(self, n_actions, fc1_dims=32, fc2_dims=32):
        super(PolicyGradientNetwork, self).__init__()
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.fc1 = Dense(self.fc1_dims, activation='relu')
        self.fc2 = Dense(self.fc2_dims, activation='relu')
        self.pi = Dense(n_actions, activation='softmax')
    def call(self, state):
        value = self.fc1(state)
        value = self.fc2(value)
        pi = self.pi(value)
        return pi


class Agent:
    def __init__(self, alpha=0.003, gamma=0.99, n_actions=4, n_k=4, num_episodes=2000, layer1_size=256, layer2_size=256):
        self.c = 1.5
        self.gamma = gamma
        self.lr = alpha
        self.n_actions = n_actions
        self.state_memory = []
        self.action_memory = []
        self.reward_memory = []
        self.state_memory_full = []
        self.action_memory_full = []
        self.reward_memory_full = []
        self.G_memory_full = []
        self.state_memory = []
        self.model_memory = []
        self.reuses = []
        self.variance = []
        self.time_elapsed = []
        self.gradient_norm = []
        self.loglikelihoods = np.zeros((num_episodes, n_k, num_episodes))
        self.policy = PolicyGradientNetwork(n_actions=n_actions)
        self.policy.compile(optimizer=SGD(learning_rate=self.lr, decay=0.0))
        # self.policy.compile(optimizer=Adam(learning_rate=self.lr))
        self._policy_hist = PolicyGradientNetwork(n_actions=n_actions)
        # self._policy_hist.compile(optimizer=SGD(learning_rate=self.lr))
    def choose_action(self, observation):
        state = tf.convert_to_tensor([observation], dtype=tf.float32)
        probs = self.policy(state)
        action_probs = tfp.distributions.Categorical(probs=probs)
        action = action_probs.sample()
        return action.numpy()[0]
    def store_transition(self, observation, action, reward):
        # (iter, r, H)
        self.state_memory = observation
        self.action_memory = action
        self.reward_memory = reward
    def compute_ilr(self):
        return
    def gradient_compute(self, model, i, j, p, n_k, H):
        with tf.GradientTape(persistent=True) as tape:
            cur_likelihood = 0
            loss = 0
            for idx, (g, state) in enumerate(zip(self.G_memory_full[i][j][:], self.state_memory_full[i][j])):
                state = tf.convert_to_tensor([state], dtype=tf.float32)
                if model == None:
                    model = self._policy_hist.set_weights(self.model_memory[p])
                probs = model(state)
                action_probs = tfp.distributions.Categorical(probs=probs)
                log_prob = action_probs.log_prob(self.action_memory_full[i][j][idx])
                # loss[j, idx] = -g * tf.squeeze(log_prob)
                loss = -g * tf.squeeze(log_prob)
                cur_likelihood += tf.squeeze(log_prob)
        return tape.gradient(loss, model.trainable_variables), cur_likelihood
    def mixture_gradient_compute(self, reuse, n_k, num_iters):
        with tf.GradientTape(persistent=True) as tape:
            loss = 0
            for i in reuse:
                for j in range(n_k):
                    numerator = np.exp(self.loglikelihoods[i, j, num_iters - 1])
                    reuse_mixture = [k for k in reuse if k >= i]
                    denominator = np.sum(np.exp(self.loglikelihoods[i, j, [k for k in reuse if k >= i]])) / len(reuse_mixture)
                    for idx, (g, state) in enumerate(zip(self.G_memory_full[i][j][:], self.state_memory_full[i][j])):
                        state = tf.convert_to_tensor([state], dtype=tf.float32)
                        probs = self.policy(state)
                        action_probs = tfp.distributions.Categorical(probs=probs)
                        log_prob = action_probs.log_prob(self.action_memory_full[i][j][idx])
                        loss += - numerator/denominator * g * tf.squeeze(log_prob)
            loss = loss / (len(reuse) * n_k)
        return tape.gradient(loss, self.policy.trainable_variables)
    def learn(self):
        # actions = tf.convert_to_tensor(self.action_memory, dtype=tf.float32)
        # rewards = np.array(self.reward_memory)
        n_k = len(self.reward_memory)
        G = {}
        for j in range(n_k):
            rewards = self.reward_memory[j]
            H = len(self.reward_memory[j])
            G_j = np.zeros_like(rewards)
            for t in range(H):
                G_sum = 0
                discount = 1
                for k in range(t, H):
                    G_sum += rewards[k] * discount
                    discount *= self.gamma
                G_j[t] = G_sum
            G[j] = G_j
        # store cur info to full
        self.G_memory_full.append(G)
        self.state_memory_full.append(self.state_memory)
        self.action_memory_full.append(self.action_memory)
        self.reward_memory_full.append(self.reward_memory)
        num_iters = len(self.reward_memory_full)
        # loss = np.zeros((n_k, H), dtype = 'float32') # tf.zeros((n_k, H))
        # cur_likelihood = np.zeros((n_k, H))
        grad_agg = []
        timer1 = time.time()
        for j in range(n_k):
            grad, ll = self.gradient_compute(self.policy, -1, j, -1, n_k, H)
            grad_numpy = [g.numpy().flatten() for g in grad]
            grad_numpy = np.concatenate(grad_numpy)
            grad_agg.append(grad_numpy)
            self.loglikelihoods[num_iters - 1, j, num_iters - 1] = ll
        policy_param_size = len(grad_numpy)
        cur_pg_variance = np.stack(grad_agg, axis=0)
        self.gradient_norm.append(np.mean(np.linalg.norm(cur_pg_variance, ord=1, axis=1)))
        cur_pg_variance = np.mean(np.linalg.norm(cur_pg_variance, ord=2, axis=1))
        self.variance.append(cur_pg_variance)
        # compute the nested likelihood ratio
        timer2 = time.time()
        gradient = np.zeros((num_iters, n_k, policy_param_size))
        for j in range(n_k):
            gradient[num_iters - 1, j, :] = grad_agg[j]
        # i-th iter
        for i in range(num_iters):
            # j-th replicate data
            for j in range(n_k):
                grad, ll = self.gradient_compute(self.policy, i, j, -1, n_k, H)
                grad_numpy = [g.numpy().flatten() for g in grad]
                grad_numpy = np.concatenate(grad_numpy)
                gradient[i, j, :] = grad_numpy
                self.loglikelihoods[i, j, num_iters-1] = ll
        loss_ilr_i_j = np.zeros((n_k, policy_param_size))
        reuse_iter = []
        for i in range(num_iters):
            for j in range(n_k):
                numerator = np.exp(self.loglikelihoods[i,j,num_iters-1])
                denominator = np.exp(self.loglikelihoods[i,j,i])
                loss_ilr_i_j[j, :] = numerator / denominator * gradient[i, j, :]
            cur_ilr_variance = np.mean(np.linalg.norm(loss_ilr_i_j, ord=2, axis=1)) # ith
            if cur_ilr_variance <= self.c * cur_pg_variance:
                reuse_iter.append(i)
        timer3 = time.time()
        self.reuses.append(reuse_iter)
        gradient = self.mixture_gradient_compute(reuse_iter, n_k, num_iters)
        self.policy.optimizer.apply_gradients(zip(gradient, self.policy.trainable_variables))
        timer4 = time.time()
        self.state_memory = []
        self.action_memory = []
        self.reward_memory = []
        self.time_elapsed.append([timer2 - timer1, timer3 -timer2, timer4 - timer3])



if __name__ == '__main__':
    index = 2
    seed = 2021 + index
    n_k = 4
    path = "./seed-{}-n_k-{}-id-{}".format(seed, n_k, index)
    num_episodes = 2000 # iteraction
    problem = "CartPole-v0" # "LunarLander-v2"
    env = gym.make(problem)
    env._max_episode_steps = 100
    num_states = env.observation_space.shape[0]
    print("Size of State Space ->  {}".format(num_states))
    num_actions = env.action_space
    print("Size of Action Space ->  {}".format(num_actions))
    env.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    agent = Agent(alpha=0.01, gamma=0.99, n_actions=2, n_k=4, num_episodes=2000)
    score_history = []
    for i in range(num_episodes):
        score = 0
        old_weights = agent.policy.get_weights()
        model = [old_weights]
        observations = {}
        actions = {}
        rewards = {}
        for j in range(n_k):
            observations[j] = []
            actions[j] = []
            rewards[j] = []
            done = False
            observation = env.reset()
            while not done:
                action = agent.choose_action(observation)
                observation_, reward, done, info = env.step(action)
                observations[j].append(observation)
                actions[j].append(action)
                rewards[j].append(reward)
                observation = observation_
                score += reward
            # print(rewards)
        agent.store_transition(observations, actions, rewards)
        score_history.append(score / n_k)
        # old_weights = agent.policy.get_weights()
        # agent.model_memory.append(old_weights)
        agent.learn()
        agent.policy.save_weights(path + "/model-{}".format(i))
        # Update running reward to check condition for solving
        avg_score = np.mean(score_history[-100:])
        print('episode: ', i,'score: %.1f' % (score / n_k),
            'average score %.1f' % avg_score)
        # template = "reuse window: {}"
        # print(template.format(agent.reuses[-1]))
        if avg_score > 95:  # Condition to consider the task solved
            print("Solved at episode {}!".format(i))
            break
# Out:
# Size of State Space ->  4
# Size of Action Space ->  Discrete(2)
# episode:  0 score: 21.8 average score 21.8
# episode:  1 score: 20.2 average score 21.0
# episode:  2 score: 36.8 average score 26.2
# episode:  3 score: 40.0 average score 29.7
# episode:  4 score: 24.5 average score 28.6
# episode:  5 score: 49.8 average score 32.2
# episode:  6 score: 22.0 average score 30.7
# episode:  7 score: 38.8 average score 31.7
# episode:  8 score: 70.5 average score 36.0
# episode:  9 score: 18.8 average score 34.3
# episode:  10 score: 56.5 average score 36.3
# episode:  11 score: 13.5 average score 34.4
# episode:  12 score: 24.2 average score 33.6
# episode:  13 score: 66.8 average score 36.0
# episode:  14 score: 18.8 average score 34.9
# episode:  15 score: 34.2 average score 34.8
# episode:  16 score: 19.5 average score 33.9
# episode:  17 score: 28.5 average score 33.6
# episode:  18 score: 71.0 average score 35.6
# episode:  19 score: 14.2 average score 34.5
# episode:  20 score: 11.0 average score 33.4
# episode:  21 score: 12.8 average score 32.5
# episode:  22 score: 11.8 average score 31.6
# episode:  23 score: 13.0 average score 30.8
# episode:  24 score: 15.0 average score 30.1
# episode:  25 score: 16.8 average score 29.6
# episode:  26 score: 14.0 average score 29.1
# episode:  27 score: 32.0 average score 29.2
# episode:  28 score: 48.8 average score 29.8
# episode:  29 score: 26.0 average score 29.7
# episode:  30 score: 36.0 average score 29.9
# episode:  31 score: 40.0 average score 30.2
# episode:  32 score: 49.8 average score 30.8
# episode:  33 score: 60.5 average score 31.7
# episode:  34 score: 26.5 average score 31.5
# episode:  35 score: 86.0 average score 33.1
# episode:  36 score: 43.2 average score 33.3
# episode:  37 score: 15.8 average score 32.9
# episode:  38 score: 17.8 average score 32.5
# episode:  39 score: 27.0 average score 32.3
# episode:  40 score: 91.8 average score 33.8
# episode:  41 score: 37.0 average score 33.9
# episode:  42 score: 63.5 average score 34.6
# episode:  43 score: 57.8 average score 35.1
# episode:  44 score: 18.2 average score 34.7
# episode:  45 score: 28.8 average score 34.6
# episode:  46 score: 41.8 average score 34.7
# episode:  47 score: 37.8 average score 34.8
# episode:  48 score: 68.0 average score 35.5
# episode:  49 score: 53.5 average score 35.8
# episode:  50 score: 24.8 average score 35.6
# episode:  51 score: 67.0 average score 36.2
# episode:  52 score: 62.0 average score 36.7
# episode:  53 score: 28.5 average score 36.6
# episode:  54 score: 45.8 average score 36.7
# episode:  55 score: 89.5 average score 37.7
# episode:  56 score: 80.5 average score 38.4
# episode:  57 score: 93.5 average score 39.4
# episode:  58 score: 34.5 average score 39.3
# episode:  59 score: 100.0 average score 40.3
# episode:  60 score: 97.8 average score 41.2
# episode:  61 score: 66.8 average score 41.6
# episode:  62 score: 63.5 average score 42.0
# episode:  63 score: 44.5 average score 42.0
# episode:  64 score: 44.5 average score 42.1
# episode:  65 score: 100.0 average score 43.0
# episode:  66 score: 100.0 average score 43.8
# episode:  67 score: 61.8 average score 44.1
# episode:  68 score: 28.0 average score 43.8
# episode:  69 score: 91.0 average score 44.5
# episode:  70 score: 87.5 average score 45.1
# episode:  71 score: 68.5 average score 45.4
# episode:  72 score: 100.0 average score 46.2
# episode:  73 score: 41.0 average score 46.1
# episode:  74 score: 75.5 average score 46.5
# episode:  75 score: 23.8 average score 46.2
# episode:  76 score: 76.5 average score 46.6
# episode:  77 score: 100.0 average score 47.3
# episode:  78 score: 82.5 average score 47.7
# episode:  79 score: 45.5 average score 47.7
# episode:  80 score: 59.2 average score 47.8
# episode:  81 score: 29.2 average score 47.6
# episode:  82 score: 69.5 average score 47.9
# episode:  83 score: 32.5 average score 47.7
# episode:  84 score: 100.0 average score 48.3
# episode:  85 score: 100.0 average score 48.9
# episode:  86 score: 24.8 average score 48.6
# episode:  87 score: 49.2 average score 48.6
# episode:  88 score: 100.0 average score 49.2
# episode:  89 score: 100.0 average score 49.8
# episode:  90 score: 100.0 average score 50.3
# episode:  91 score: 26.8 average score 50.1
# episode:  92 score: 91.8 average score 50.5
# episode:  93 score: 80.2 average score 50.8
# episode:  94 score: 100.0 average score 51.4
# episode:  95 score: 89.2 average score 51.8
# episode:  96 score: 17.5 average score 51.4
# episode:  97 score: 100.0 average score 51.9
# episode:  98 score: 100.0 average score 52.4
# episode:  99 score: 80.0 average score 52.7
# episode:  100 score: 37.8 average score 52.8
# episode:  101 score: 100.0 average score 53.6
# episode:  102 score: 100.0 average score 54.3
# episode:  103 score: 92.5 average score 54.8
# episode:  104 score: 98.8 average score 55.5
# episode:  105 score: 71.8 average score 55.7
# episode:  106 score: 91.0 average score 56.4
# episode:  107 score: 69.0 average score 56.7
# episode:  108 score: 28.5 average score 56.3
# episode:  109 score: 40.2 average score 56.5
# episode:  110 score: 100.0 average score 57.0
# episode:  111 score: 87.0 average score 57.7
# episode:  112 score: 30.0 average score 57.8
# episode:  113 score: 57.8 average score 57.7
# episode:  114 score: 100.0 average score 58.5
# episode:  115 score: 67.8 average score 58.8
# episode:  116 score: 48.2 average score 59.1
# episode:  117 score: 100.0 average score 59.8
# episode:  118 score: 100.0 average score 60.1
# episode:  119 score: 47.2 average score 60.4
# episode:  120 score: 99.5 average score 61.3
# episode:  121 score: 44.0 average score 61.6
# episode:  122 score: 31.5 average score 61.8
# episode:  123 score: 55.8 average score 62.3
# episode:  124 score: 100.0 average score 63.1
# episode:  125 score: 100.0 average score 63.9
# episode:  126 score: 17.8 average score 64.0
# episode:  127 score: 54.8 average score 64.2
# episode:  128 score: 100.0 average score 64.7
# episode:  129 score: 20.5 average score 64.7
# episode:  130 score: 100.0 average score 65.3
# episode:  131 score: 82.8 average score 65.7
# episode:  132 score: 44.2 average score 65.7
# episode:  133 score: 100.0 average score 66.1
# episode:  134 score: 100.0 average score 66.8
# episode:  135 score: 49.0 average score 66.4
# episode:  136 score: 86.0 average score 66.9
# episode:  137 score: 98.0 average score 67.7
# episode:  138 score: 100.0 average score 68.5
# episode:  139 score: 85.2 average score 69.1
# episode:  140 score: 100.0 average score 69.2
# episode:  141 score: 78.5 average score 69.6
# episode:  142 score: 87.2 average score 69.8
# episode:  143 score: 100.0 average score 70.2
# episode:  144 score: 100.0 average score 71.1
# episode:  145 score: 81.2 average score 71.6
# episode:  146 score: 100.0 average score 72.2
# episode:  147 score: 75.2 average score 72.5
# episode:  148 score: 100.0 average score 72.9
# episode:  149 score: 100.0 average score 73.3
# episode:  150 score: 100.0 average score 74.1
# episode:  151 score: 100.0 average score 74.4
# episode:  152 score: 85.5 average score 74.7
# episode:  153 score: 19.2 average score 74.6
# episode:  154 score: 61.0 average score 74.7
# episode:  155 score: 100.0 average score 74.8
# episode:  156 score: 66.8 average score 74.7
# episode:  157 score: 100.0 average score 74.7
# episode:  158 score: 100.0 average score 75.4
# episode:  159 score: 100.0 average score 75.4
# episode:  160 score: 42.5 average score 74.8
# episode:  161 score: 100.0 average score 75.2
# episode:  162 score: 100.0 average score 75.5
# episode:  163 score: 90.2 average score 76.0
# episode:  164 score: 92.0 average score 76.5
# episode:  165 score: 100.0 average score 76.5
# episode:  166 score: 100.0 average score 76.5
# episode:  167 score: 100.0 average score 76.9
# episode:  168 score: 100.0 average score 77.6
# episode:  169 score: 100.0 average score 77.7
# episode:  170 score: 88.2 average score 77.7
# episode:  171 score: 100.0 average score 78.0
# episode:  172 score: 100.0 average score 78.0
# episode:  173 score: 65.2 average score 78.2
# episode:  174 score: 100.0 average score 78.5
# episode:  175 score: 100.0 average score 79.2
# episode:  176 score: 100.0 average score 79.5
# episode:  177 score: 46.5 average score 78.9
# episode:  178 score: 87.0 average score 79.0
# episode:  179 score: 100.0 average score 79.5
# episode:  180 score: 68.0 average score 79.6
# episode:  181 score: 100.0 average score 80.3
# episode:  182 score: 100.0 average score 80.6
# episode:  183 score: 99.5 average score 81.3
# episode:  184 score: 100.0 average score 81.3
# episode:  185 score: 100.0 average score 81.3
# episode:  186 score: 100.0 average score 82.1
# episode:  187 score: 82.2 average score 82.4
# episode:  188 score: 51.0 average score 81.9
# episode:  189 score: 85.5 average score 81.7
# episode:  190 score: 79.5 average score 81.5
# episode:  191 score: 100.0 average score 82.3
# episode:  192 score: 74.0 average score 82.1
# episode:  193 score: 100.0 average score 82.3
# episode:  194 score: 100.0 average score 82.3
# episode:  195 score: 47.2 average score 81.9
# episode:  196 score: 100.0 average score 82.7
# episode:  197 score: 64.2 average score 82.3
# episode:  198 score: 100.0 average score 82.3
# episode:  199 score: 83.0 average score 82.4
# episode:  200 score: 100.0 average score 83.0
# episode:  201 score: 100.0 average score 83.0
# episode:  202 score: 98.8 average score 83.0
# episode:  203 score: 100.0 average score 83.1
# episode:  204 score: 100.0 average score 83.1
# episode:  205 score: 100.0 average score 83.4
# episode:  206 score: 100.0 average score 83.4
# episode:  207 score: 100.0 average score 83.8
# episode:  208 score: 98.8 average score 84.5
# episode:  209 score: 100.0 average score 85.1
# episode:  210 score: 83.2 average score 84.9
# episode:  211 score: 100.0 average score 85.0
# episode:  212 score: 100.0 average score 85.7
# episode:  213 score: 99.5 average score 86.1
# episode:  214 score: 100.0 average score 86.1
# episode:  215 score: 100.0 average score 86.5
# episode:  216 score: 81.8 average score 86.8
# episode:  217 score: 39.2 average score 86.2
# episode:  218 score: 100.0 average score 86.2
# episode:  219 score: 100.0 average score 86.7
# episode:  220 score: 100.0 average score 86.7
# episode:  221 score: 69.0 average score 87.0
# episode:  222 score: 100.0 average score 87.7
# episode:  223 score: 100.0 average score 88.1
# episode:  224 score: 100.0 average score 88.1
# episode:  225 score: 46.2 average score 87.6
# episode:  226 score: 100.0 average score 88.4
# episode:  227 score: 82.5 average score 88.7
# episode:  228 score: 100.0 average score 88.7
# episode:  229 score: 100.0 average score 89.5
# episode:  230 score: 100.0 average score 89.5
# episode:  231 score: 100.0 average score 89.6
# episode:  232 score: 82.8 average score 90.0
# episode:  233 score: 100.0 average score 90.0
# episode:  234 score: 82.0 average score 89.8
# episode:  235 score: 71.2 average score 90.0
# episode:  236 score: 56.0 average score 89.8
# episode:  237 score: 100.0 average score 89.8
# episode:  238 score: 100.0 average score 89.8
# episode:  239 score: 100.0 average score 89.9
# episode:  240 score: 100.0 average score 89.9
# episode:  241 score: 100.0 average score 90.1
# episode:  242 score: 80.2 average score 90.1
# episode:  243 score: 89.5 average score 90.0
# episode:  244 score: 100.0 average score 90.0
# episode:  245 score: 99.8 average score 90.1
# episode:  246 score: 100.0 average score 90.1
# episode:  247 score: 100.0 average score 90.4
# episode:  248 score: 100.0 average score 90.4
# episode:  249 score: 100.0 average score 90.4
# episode:  250 score: 100.0 average score 90.4
# episode:  251 score: 78.2 average score 90.2
# episode:  252 score: 100.0 average score 90.3
# episode:  253 score: 100.0 average score 91.1
# episode:  254 score: 80.2 average score 91.3
# episode:  255 score: 100.0 average score 91.3
# episode:  256 score: 100.0 average score 91.7
# episode:  257 score: 100.0 average score 91.7
# episode:  258 score: 100.0 average score 91.7
# episode:  259 score: 100.0 average score 91.7
# episode:  260 score: 100.0 average score 92.2
# episode:  261 score: 100.0 average score 92.2
# episode:  262 score: 100.0 average score 92.2
# episode:  263 score: 79.8 average score 92.1
# episode:  264 score: 100.0 average score 92.2
# episode:  265 score: 100.0 average score 92.2
# episode:  266 score: 96.2 average score 92.2
# episode:  267 score: 80.2 average score 92.0
# episode:  268 score: 100.0 average score 92.0
# episode:  269 score: 100.0 average score 92.0
# episode:  270 score: 100.0 average score 92.1
# episode:  271 score: 83.5 average score 91.9
# episode:  272 score: 100.0 average score 91.9
# episode:  273 score: 100.0 average score 92.3
# episode:  274 score: 99.5 average score 92.3
# episode:  275 score: 100.0 average score 92.3
# episode:  276 score: 80.0 average score 92.1
# episode:  277 score: 100.0 average score 92.6
# episode:  278 score: 100.0 average score 92.7
# episode:  279 score: 100.0 average score 92.7
# episode:  280 score: 100.0 average score 93.0
# episode:  281 score: 100.0 average score 93.0
# episode:  282 score: 100.0 average score 93.0
# episode:  283 score: 100.0 average score 93.0
# episode:  284 score: 100.0 average score 93.0
# episode:  285 score: 100.0 average score 93.0
# episode:  286 score: 100.0 average score 93.0
# episode:  287 score: 100.0 average score 93.2

# %%
np.save('cartpole-fixed0.01-mlr',score_history)
